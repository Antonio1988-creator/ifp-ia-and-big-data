# %% [markdown]
# ## EJERCICIO DE REPASO: MATRICES, ESTADÍSTICA Y REGRESIÓN LINEAL
#
#
# ---

# %% [markdown]
# ### PARTE A — MATRICES

# %%
import numpy as np

# Definimos las matrices para los ejercicios
A = np.array([[2,0],[1,4],[3,5]])
B = np.array([[6,9,2],[8,1,7]])

print("Matriz A:")
print(A)
print("\nMatriz B:")
print(B)
# Out:
# Matriz A:
# [[2 0]
#  [1 4]
#  [3 5]]
#
# Matriz B:
# [[6 9 2]
#  [8 1 7]]

# %% [markdown]
# #### Ejercicio 1
#
# Sea:
# ```
# A = [[2,0],
#      [1,4],
#      [3,5]]
# B = [[6,9,2],
#      [8,1,7]]
# ```
#
# a) Dimensiones de A y B.
#
# b) Elementos A_3,2 y B_2,1.
#
# c) ¿Es posible sumar A + B? Justifica.

# %%
# Solución Ejercicio 1
# Escribe aquí tu solución para el Ejercicio 1

# %%
C = np.array([[4,1],[-2,3]])
D = np.array([[0,5],[6,-1]])

print("Matriz C:")
print(C)
print("\nMatriz D:")
print(D)
# Out:
# Matriz C:
# [[ 4  1]
#  [-2  3]]
#
# Matriz D:
# [[ 0  5]
#  [ 6 -1]]

# %% [markdown]
# #### Ejercicio 2
#
# Sea:
# ```
# C = [[4,1],
#      [-2,3]]
# D = [[0,5],
#      [6,-1]]
# ```
#
# a) C + D.
#
# b) C - D.
#
# c) Condición para sumar matrices.

# %%
# Solución Ejercicio 2
# Escribe aquí tu solución para el Ejercicio 2

# %%
E = np.array([[2,-1,3],[0,4,1]])
alfa = -2

print("Matriz E:")
print(E)
print(f"Escalar alfa: {alfa}")
# Out:
# Matriz E:
# [[ 2 -1  3]
#  [ 0  4  1]]
# Escalar alfa: -2

# %% [markdown]
# #### Ejercicio 3
#
# Sea:
# ```
# E = [[2,-1,3],
#      [0,4,1]]
# α = -2
# ```
#
# a) -2E.
#
# b) Dimensiones resultantes.

# %%
# Solución Ejercicio 3
# Escribe aquí tu solución para el Ejercicio 3

# %%
F = np.array([[2,1],[0,3]])
G = np.array([[1,4],[5,2]])

print("Matriz F:")
print(F)
print("\nMatriz G:")
print(G)
# Out:
# Matriz F:
# [[2 1]
#  [0 3]]
#
# Matriz G:
# [[1 4]
#  [5 2]]

# %% [markdown]
# #### Ejercicio 4
#
# Sea:
# ```
# F = [[2,1],
#      [0,3]]
# G = [[1,4],
#      [5,2]]
# ```
#
# a) FG.
#
# b) ¿FG = GF? Demuéstralo con el cálculo.
#
# c) Condición del producto matricial.

# %%
# Solución Ejercicio 4
# Escribe aquí tu solución para el Ejercicio 4

# %%
H = np.array([[3,1,0],[2,5,4]])

print("Matriz H:")
print(H)
# Out:
# Matriz H:
# [[3 1 0]
#  [2 5 4]]

# %% [markdown]
# #### Ejercicio 5
#
# Sea:
# ```
# H = [[3,1,0],
#      [2,5,4]]
# ```
#
# a) H^T (Transpuesta de H).
#
# b) Dimensión de la transpuesta.

# %%
# Solución Ejercicio 5
# Escribe aquí tu solución para el Ejercicio 5

# %% [markdown]
# ---

# %% [markdown]
# ### PARTE B — ESTADÍSTICA Y MODELOS

# %%
X_ej6 = np.array([1,3,3,4,6,8])
print(f"Datos para Ejercicio 6 (X): {X_ej6}")
# Out:
# Datos para Ejercicio 6 (X): [1 3 3 4 6 8]

# %% [markdown]
# #### Ejercicio 6
#
# Sea el conjunto de datos:
# ```
# X = [1,3,3,4,6,8]
# ```
#
# a) Media.
#
# b) Varianza (poblacional).
#
# c) Desviación estándar (poblacional).

# %%
# Solución Ejercicio 6
# Escribe aquí tu solución para el Ejercicio 6

# %%
X_ej7 = np.array([2,4,6,8,10])
Y_ej7 = np.array([1,2,4,3,5])

print(f"Datos para Ejercicio 7 (X): {X_ej7}")
print(f"Datos para Ejercicio 7 (Y): {Y_ej7}")
# Out:
# Datos para Ejercicio 7 (X): [ 2  4  6  8 10]
# Datos para Ejercicio 7 (Y): [1 2 4 3 5]

# %% [markdown]
# #### Ejercicio 7
#
# Sea los conjuntos de datos:
# ```
# X = [2,4,6,8,10]
# Y = [1,2,4,3,5]
# ```
#
# a) Covarianza (poblacional).
#
# b) Interpretación de la covarianza obtenida.

# %%
# Solución Ejercicio 7
# Escribe aquí tu solución para el Ejercicio 7

# %% [markdown]
# #### Ejercicio 8
#
# **Coeficiente de correlación de Pearson (r):**
#
# a) Definición.
#
# b) Rango e interpretación de sus valores.

# %% [markdown]
# #### Ejercicio 9
#
# **Modelo de regresión lineal simple:** `y = β0 + β1 x + ε`
#
# a) Significado de cada uno de los términos del modelo.
#
# b) Objetivo del método de Mínimos Cuadrados Ordinarios (OLS).

# %% [markdown]
# #### Ejercicio 10
#
# Definición de SST (Suma Total de Cuadrados), SSR (Suma de Cuadrados de la Regresión) y SSE (Suma de Cuadrados del Error).
#
# Relación matemática entre ellas.

# %% [markdown]
# #### Ejercicio 11
#
# **Coeficiente de determinación R²:**
#
# Definición e interpretación de su valor.

# %% [markdown]
# ---

# %% [markdown]
# ### PARTE C — APLICACIÓN (Regresión Lineal Simple)

# %%
X_app = np.array([0,1,2,3,4])
Y_app = np.array([1,2.2,2.9,3.8,5.1])

print(f"Datos X para aplicación: {X_app}")
print(f"Datos Y para aplicación: {Y_app}")
# Out:
# Datos X para aplicación: [0 1 2 3 4]
# Datos Y para aplicación: [1.  2.2 2.9 3.8 5.1]

# %% [markdown]
# #### Ejercicio 12
#
# Sea los conjuntos de datos:
# ```
# X = [0,1,2,3,4]
# Y = [1,2.2,2.9,3.8,5.1]
# ```
#
# Construcción de la matriz de diseño (matriz X grande) para el modelo de regresión lineal simple, asumiendo un intercepto.

# %%
# Solución Ejercicio 12
# Escribe aquí tu solución para el Ejercicio 12

# %% [markdown]
# #### Ejercicio 13
#
# Cálculo de los coeficientes `β` (β0 y β1) usando la fórmula matricial de Mínimos Cuadrados Ordinarios (OLS): `β = (XᵀX)⁻¹XᵀY`.

# %%
# Solución Ejercicio 13
# Escribe aquí tu solución para el Ejercicio 13

# %% [markdown]
# #### Ejercicio 14
#
# Calcula los valores predichos (`ŷ`) y los residuos (`e`) para cada observación utilizando los coeficientes `β` obtenidos.

# %%
# Solución Ejercicio 14
# Escribe aquí tu solución para el Ejercicio 14

# %% [markdown]
# #### Ejercicio 15
#
# Calcula e interpreta el Coeficiente de Determinación (R²) para el modelo ajustado.

# %%
# Solución Ejercicio 15
# Escribe aquí tu solución para el Ejercicio 15
